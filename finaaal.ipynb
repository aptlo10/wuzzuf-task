# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup    
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
data_wuzzuf=pd.read_csv('E:/ffinaal/data_science_dataset_wuzzuf.csv')

# %%
data_wuzzuf.head()
# Out:
#          id             city_name              displayed_job_title  \
# 0  5d4b2419                  Ciro          Sales & Marketing Agent
# 1  bd9ecd07                 Cairo     German Training Coordinator
# 2  3096c0f2                 Cairo       Junior Software Developer
# 3  a99f9148                 Cairo     Application Support Engineer
# 4  37fb04eb  6 th of October city  e-payments System Administrator
#
#                       job_category_1  job_category_2   job_category_3  \
# 0  Sales/Retail/Business Development       Marketing           Select
# 1           Customer Service/Support  Administration  Human Resources
# 2            IT/Software Development          Select           Select
# 3            IT/Software Development          Select           Select
# 4            IT/Software Development          Select           Select
#
#                     job_industry_1             job_industry_2 job_industry_3  \
# ...

# %%
data_wuzzuf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21850 entries, 0 to 21849
# Data columns (total 18 columns):
# id                     21850 non-null object
# city_name              21850 non-null object
# displayed_job_title    21850 non-null object
# job_category_1         21850 non-null object
# job_category_2         21850 non-null object
# job_category_3         21850 non-null object
# job_industry_1         21850 non-null object
# job_industry_2         21850 non-null object
# job_industry_3         21850 non-null object
# salary_min             21850 non-null int64
# salary_max             21850 non-null int64
# num_vacancies          21850 non-null int64
# career_level           21850 non-null object
# experience_years       21850 non-null object
# post_date              21850 non-null object
# views                  21850 non-null int64
# description            21576 non-null object
# job_requirements       19217 non-null object
# dtypes: int64(4), object(14)
# ...

# %%
data_wuzzuf['description'] = data_wuzzuf['description'].astype(str)

# %%
def review_to_words( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(raw_review).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    
    return( " ".join( words))

# %%
job_desc = []
for i in range(0, 21850):
    job_desc.append(review_to_words(data_wuzzuf['description'][i]))
# Out:
# C:\anaconda\lib\site-packages\bs4\__init__.py:182: UserWarning: "." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   '"%s" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.' % markup)

# %%
job_desc[0]
# Out:
# u'qualifications graduates and undergraduates are encouraged to apply telesales experience months at least proficiency in using ms office application word excel strong verbal communication and negotiation skills demonstrates a positive enthusiastic friendly and professional attitude english skills fluent job details and benefits available start date in weeks working hours hours location maadi cairo job package basic salary egp commission when target is acheived'

# %%
data_wuzzuf['job_requirements']=data_wuzzuf['job_requirements'].astype(str)

# %%
job_req = []
for i in range(0, 21850):
    job_req.append(review_to_words(data_wuzzuf['job_requirements'][i]))

# %%
job_req[7400]
# Out:
# u'technical skills excellent knowledge in vb or c excellent knowledge in object oriented design good knowledge of software development process good knowledge in microsoft sql and relational database groovy knowledge is a plus proficient in several development environments web services asp j ee and net language proficiency in english essential written and spoken second language much appreciated personal skills excellent team spirit able to work under pressure as part of delivery team date commitment international pro active and motivated team member able to work on multi site projects comfortable with traveling and dealing with customers'

# %%
data_wuzzuf['experience_years']=data_wuzzuf['experience_years'].astype(str)

# %%
#clean experience_years
def review_to_words(raw_review ):
    review_text = BeautifulSoup(raw_review).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^-1-9]+", " ", review_text) 
    return( "".join(letters_only))

# %%
job_exp = []
for i in range(0, 21850):
    job_exp.append(review_to_words(data_wuzzuf["experience_years"][i]))

# %%
job_desc[0]
# Out:
# u'qualifications graduates and undergraduates are encouraged to apply telesales experience months at least proficiency in using ms office application word excel strong verbal communication and negotiation skills demonstrates a positive enthusiastic friendly and professional attitude english skills fluent job details and benefits available start date in weeks working hours hours location maadi cairo job package basic salary egp commission when target is acheived'

# %%
job_req[7400]
# Out:
# u'technical skills excellent knowledge in vb or c excellent knowledge in object oriented design good knowledge of software development process good knowledge in microsoft sql and relational database groovy knowledge is a plus proficient in several development environments web services asp j ee and net language proficiency in english essential written and spoken second language much appreciated personal skills excellent team spirit able to work under pressure as part of delivery team date commitment international pro active and motivated team member able to work on multi site projects comfortable with traveling and dealing with customers'

# %%
job_exp[106]
# Out:
# u'1 2 '

# %%
#delete old coumumns
data_wuzzuf.drop(['description','job_requirements','experience_years'],axis=1,inplace=True)

# %%
#create new coulmn in w data frame

data_wuzzuf['job_desc']=job_desc
data_wuzzuf['job_req']=job_req
data_wuzzuf['job_exp']=job_exp

# %%
data_wuzzuf.head()
# Out:
#          id             city_name              displayed_job_title  \
# 0  5d4b2419                  Ciro          Sales & Marketing Agent
# 1  bd9ecd07                 Cairo     German Training Coordinator
# 2  3096c0f2                 Cairo       Junior Software Developer
# 3  a99f9148                 Cairo     Application Support Engineer
# 4  37fb04eb  6 th of October city  e-payments System Administrator
#
#                       job_category_1  job_category_2   job_category_3  \
# 0  Sales/Retail/Business Development       Marketing           Select
# 1           Customer Service/Support  Administration  Human Resources
# 2            IT/Software Development          Select           Select
# 3            IT/Software Development          Select           Select
# 4            IT/Software Development          Select           Select
#
#                     job_industry_1             job_industry_2 job_industry_3  \
# ...

# %%
data_wuzzuf['city_name'] = data_wuzzuf['city_name'].astype(str)

# %%
#export it to csv file

data_wuzzuf.to_csv('E:/ffinaal/clean1.csv', sep='\t')

# %%
data_wuzzuf['city_name'].value_counts()
# Out:
# Cairo                                                      14988
# Giza                                                        3886
# Alexandria                                                   989
# 6th of October                                                90
# Mansoura                                                      89
# New Cairo                                                     85
# 10th of Ramadan                                               81
# Any                                                           60
# Giza / Cairo                                                  45
# Ismailia                                                      39
# 10th of ramadan city                                          36
# Cairo / Giza                                                  36
# 6th of October City                                           35
# Tanta                                                         32
# ...

# %%
"""
in city column there is bad insertion so 
 import csv file to  excel file to make fuzzy wuzzy funcation in column city_name
first rearrnage columns with excel 2016
seconde  copy coilumn city name to another excell file then make fuzzy wuzzy funcation that 
compare the city column with real city column and get similarty ratoi between tow text 
that have no spelling mistakes becouse city columns have at lest 400 mistakes
i made fuzzy wuzzy   funcation in next sheet in excel file 
also make some find and repalce with excel to solve some mistakes insertion 
then import here again for analysis

"""
# Out:
# '\nin city column there is bad insertion so \n import csv file to  excel file to make fuzzy wuzzy funcation in column city_name\nfirst rearrnage columns with excel 2016\nseconde  copy coilumn city name to another excell file then make fuzzy wuzzy funcation that \ncompare the city column with real city column and get similarty ratoi between tow text \nthat have no spelling mistakes becouse city columns have at lest 400 mistakes\ni made fuzzy wuzzy   funcation in next sheet in excel file \nalso make some find and repalce with excel to solve some mistakes insertion \nthen import here again for analysis\n\n'

# %%
# save new clean data to new file for visualization in tableau
#now we make some   analysis to all  data

# %%
data_wuzzuf_clean=pd.read_excel('E:/ffinaal/final.xlsx')

# %%
# save new clean data to new file for visualization in tableau
#now we make some   analysis to all  data

# %%
data_wuzzuf_clean.head()
# Out:
#          id               city              displayed_job_title  \
# 0  5d4b2419              Cairo          Sales & Marketing Agent
# 1  bd9ecd07              Cairo     German Training Coordinator
# 2  3096c0f2              Cairo       Junior Software Developer
# 3  a99f9148              Cairo     Application Support Engineer
# 4  37fb04eb  6 of October City  e-payments System Administrator
#
#                       job_category_1  job_category_2   job_category_3  \
# 0  Sales/Retail/Business Development       Marketing           Select
# 1           Customer Service/Support  Administration  Human Resources
# 2            IT/Software Development          Select           Select
# 3            IT/Software Development          Select           Select
# 4            IT/Software Development          Select           Select
#
#                     job_industry_1             job_industry_2 job_industry_3  \
# 0      Telecommunications Services                     Select         Select
# ...

# %%
"""
in tablue we will do some analysis for all data but gere we will do some anyliese to job_category_1
so we can understand the relation between variables eche other with every job category alone

"""
# Out:
# '\nin tablue we will do some analysis for all data but gere we will do some anyliese to job_category_1\nso we can understand the relation between variables eche other with every job category alone\n\n'

# %%
data_wuzzuf_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21850 entries, 0 to 21849
# Data columns (total 18 columns):
# id                     21850 non-null object
# city                   21850 non-null object
# displayed_job_title    21850 non-null object
# job_category_1         21850 non-null object
# job_category_2         21850 non-null object
# job_category_3         21850 non-null object
# job_industry_1         21850 non-null object
# job_industry_2         21850 non-null object
# job_industry_3         21850 non-null object
# salary_min             21850 non-null int64
# salary_max             21850 non-null int64
# num_vacancies          21850 non-null int64
# career_level           21850 non-null object
# post_date              21850 non-null datetime64[ns]
# views                  21850 non-null int64
# job_desc               21214 non-null object
# job_req                18946 non-null object
# job_exp                21850 non-null object
# ...

# %%
data_wuzzuf_clean.describe()
# Out:
#           salary_min      salary_max  num_vacancies         views
# count   21850.000000    21850.000000   21850.000000  21850.000000
# mean     3333.283982     5476.040412       5.856934   1376.874737
# std      5293.894787    10783.029504      16.633904   1065.109847
# min         0.000000        0.000000       1.000000      0.000000
# 25%      1500.000000     2500.000000       1.000000    797.000000
# 50%      2500.000000     4000.000000       1.000000   1230.000000
# 75%      3500.000000     6000.000000       3.000000   1791.000000
# max    250000.000000  1000000.000000     100.000000  37568.000000

# %%
"""
describe by job category 

"""
# Out:
# '\ndescribe by job category \n\n'

# %%
job_category=data_wuzzuf_clean.groupby(['job_category_1']).mean()

# %%
type(job_category)
# Out:
# pandas.core.frame.DataFrame

# %%
job_category.sort_values('views',ascending=True)
# Out:
#                                        salary_min    salary_max  \
# job_category_1
# Sports and Leisure                    1490.818182   2818.181818
# Business                              4958.064516   7527.419355
# Sales/Retail/Business Development     2863.176677   4876.769269
# Marketing                             3034.761004   4974.647876
# Food Services/Hospitality             2759.433962  23432.075472
# Fashion                               2963.636364   4845.454545
# Creative/Design                       2509.948014   4349.719626
# IT/Software Development               4145.127560   6613.300937
# Media/Journalism/Publishing           3285.937500   5061.607143
# Pharmaceutical                        3610.280374   5357.476636
# Biotech/R&D/Science                   2590.566038   4016.820755
# Research                              3008.352941   4654.352941
# Accounting/Finance/Insurance          2696.839286   4984.732143
# ...

# %%
it_softt=data_wuzzuf_clean[data_wuzzuf_clean['job_category_1']==('IT/Software Development')]

# %%
it_softt
# Out:
#                                                       id               city  \
# 2                                               3096c0f2              Cairo
# 3                                               a99f9148              Cairo
# 4                                               37fb04eb  6 of October City
# 6                                               d9f565c7              Cairo
# 8                                               40fc347d              Cairo
# 10                                              164ff05e              Cairo
# 12                                              8f46a1e4              Cairo
# 14                                              ff2c556b              Cairo
# 23                                              9c2a39b2              Cairo
# 24                                              eb2d0924              Cairo
# 25                                              75499c87              Cairo
# ...

# %%
"""
we do some analysis to it job category ,
this analysis here can do for all job categories but here an example for that"""
# Out:
# '\nwe do some analysis to it job category ,\nthis analysis here can do for all job categories but here an example for that'

# %%
#export the data ti csv file for using it in tableu
it_softt.to_csv('it_soft.csv', sep='\t',encoding='utf8')

# %%
it_softt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5762 entries, 2 to 21843
# Data columns (total 18 columns):
# id                     5762 non-null object
# city                   5762 non-null object
# displayed_job_title    5762 non-null object
# job_category_1         5762 non-null object
# job_category_2         5762 non-null object
# job_category_3         5762 non-null object
# job_industry_1         5762 non-null object
# job_industry_2         5762 non-null object
# job_industry_3         5762 non-null object
# salary_min             5762 non-null int64
# salary_max             5762 non-null int64
# num_vacancies          5762 non-null int64
# career_level           5762 non-null object
# post_date              5762 non-null datetime64[ns]
# views                  5762 non-null int64
# job_desc               5703 non-null object
# job_req                5056 non-null object
# job_exp                5762 non-null object
# dtypes: datetime64[ns](1), int64(4), object(13)
# ...

# %%
#convert columns type to string
it_softt['job_desc'] = it_softt['job_desc'].astype(str)
it_softt['job_req'] = it_softt['job_req'].astype(str)
# Out:
# C:\anaconda\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\anaconda\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
"""
now using CountVectorizerto count most usimg words in three columns 
 job description / job requirement  / job title

"""
# Out:
# '\nnow using CountVectorizerto count most usimg words in three columns \n job description / job requirement  / job title\n\n'

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
jobdesc = CountVectorizer(analyzer=review_to_words).fit(it_softt['job_desc'])
jobdreq = CountVectorizer(analyzer=review_to_words).fit(it_softt['job_req'])
job_title = CountVectorizer(analyzer=review_to_words).fit(it_softt['displayed_job_title'])

# %%
job_decsr=it_softt['job_desc']

# %%
job_requr=it_softt['job_req']

# %%
job_title=it_softt['displayed_job_title']

# %%
# Print total number of vocab words
print(len(jobdreq.vocabulary_))
# Out:
# 1

# %%
print(len(jobdesc.vocabulary_))
# Out:
# 1

# %%
vectorizer = CountVectorizer(analyzer = "word",   
                             tokenizer = None,    
                             preprocessor = None, 
                             stop_words = None,   
                             max_features = 500)

# %%
vectorizer1 = CountVectorizer(analyzer = "word",   
                             tokenizer = None,    
                             preprocessor = None, 
                             stop_words = None,   
                             max_features = 500)

# %%
vectorizer2 = CountVectorizer(analyzer = "word",   
                             tokenizer = None,    
                             preprocessor = None, 
                             stop_words = None,   
                             max_features = 500)

# %%
train_data_desc_features = vectorizer.fit_transform(job_decsr)

# %%
train_data_requ_features = vectorizer1.fit_transform(job_requr)

# %%
train_data_title_features = vectorizer2.fit_transform(job_title)

# %%
train_data_desc_features = train_data_desc_features.toarray()

# %%
train_data_requ_features = train_data_requ_features .toarray()

# %%
train_data_title_features = train_data_title_features.toarray()

# %%
print train_data_desc_features.shape
# Out:
# (5762L, 500L)

# %%
print train_data_requ_features.shape
# Out:
# (5762L, 500L)

# %%
print train_data_title_features.shape
# Out:
# (5762L, 500L)

# %%
job_descr = vectorizer.get_feature_names()
print job_descr
# Out:
# [u'ability', u'able', u'about', u'access', u'according', u'across', u'activities', u'administration', u'advanced', u'agile', u'ajax', u'all', u'also', u'an', u'analysis', u'analyze', u'analyzing', u'and', u'android', u'any', u'apis', u'app', u'application', u'applications', u'apply', u'appropriate', u'apps', u'architecture', u'are', u'areas', u'as', u'asp', u'aspects', u'assigned', u'assist', u'assistance', u'at', u'automation', u'back', u'backup', u'based', u'basic', u'be', u'best', u'between', u'both', u'bug', u'bugs', u'build', u'building', u'business', u'but', u'by', u'cairo', u'can', u'candidate', u'candidates', u'cases', u'changes', u'client', u'clients', u'closely', u'cloud', u'code', u'coding', u'collaborate', u'communicate', u'communication', u'companies', u'company', u'complete', u'completion', u'complex', u'components', u'computer', u'concepts', u'conduct', u'configuration', u'configure', u'configuring', u'content', u'continuously', u'contribute', u'control', u'core', u'cr
# ...

# %%
job_requir = vectorizer1.get_feature_names()
print job_requir
# Out:
# [u'ability', u'able', u'about', u'across', u'active', u'administration', u'adobe', u'advanced', u'advantage', u'agile', u'ajax', u'all', u'also', u'an', u'analysis', u'analytical', u'and', u'android', u'angular', u'angularjs', u'any', u'apache', u'api', u'apis', u'app', u'application', u'applications', u'apply', u'approach', u'apps', u'arabic', u'architecture', u'architectures', u'are', u'as', u'asp', u'asset', u'at', u'attention', u'attitude', u'automated', u'awareness', u'bachelor', u'back', u'background', u'based', u'basic', u'be', u'best', u'big', u'bootstrap', u'both', u'browser', u'bs', u'bsc', u'build', u'building', u'business', u'but', u'by', u'can', u'candidate', u'candidates', u'ccna', u'certification', u'certified', u'clean', u'clear', u'client', u'clients', u'cloud', u'cms', u'cocoa', u'code', u'codeigniter', u'coding', u'command', u'commitment', u'common', u'communicate', u'communication', u'communications', u'complex', u'components', u'computer', u'concept', u'concepts'
# ...

# %%
job_title = vectorizer2.get_feature_names()
print job_title
# Out:
# [u'000', u'13', u'15', u'2013', u'30', u'3d', u'500', u'6th', u'75', u'abap', u'account', u'accounting', u'adf', u'admin', u'administration', u'administrator', u'adminstrator', u'adsl', u'agent', u'agile', u'ai', u'alexanderia', u'alexandria', u'analyst', u'and', u'andriod', u'android', u'angular', u'angularjs', u'apex', u'app', u'application', u'applications', u'apps', u'arabia', u'architect', u'architecture', u'artificial', u'asp', u'assistant', u'associate', u'assurance', u'aswan', u'asyut', u'at', u'atg', u'atm', u'auditor', u'autocad', u'autodesk', u'automation', u'automotive', u'avaya', u'aws', u'ax', u'azure', u'b1', u'back', u'backend', u'background', u'banking', u'base', u'based', u'basis', u'bi', u'big', u'billing', u'biomedical', u'biztalk', u'bobj', u'boy', u'bpm', u'branches', u'bss', u'build', u'building', u'business', u'bw', u'by', u'cairo', u'cakephp', u'call', u'canada', u'capacity', u'care', u'case', u'cassandra', u'ccna', u'ce', u'center', u'chain', u'chandigarh', 
# ...

# %%
# Sum up the counts of each vocabulary word
dist = np.sum(train_data_desc_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(job_descr, dist):
    print tag,count
# Out:
# ability 875
# able 359
# about 496
# access 217
# according 358
# across 344
# activities 553
# administration 309
# advanced 271
# agile 271
# ajax 226
# all 1798
# also 480
# an 1596
# analysis 1202
# analyze 451
# analyzing 243
# and 39214
# android 619
# any 489
# apis 198
# app 233
# application 1927
# applications 3442
# apply 274
# appropriate 395
# apps 491
# architecture 474
# are 2547
# areas 198
# as 3438
# asp 393
# aspects 225
# assigned 449
# assist 453
# assistance 188
# at 924
# automation 201
# back 343
# backup 235
# based 1056
# basic 205
# be 3090
# best 669
# between 253
# both 435
# bug 328
# bugs 288
# build 826
# building 509
# business 2339
# but 253
# by 1751
# cairo 190
# can 548
# candidate 574
# candidates 213
# cases 489
# changes 289
# client 885
# clients 742
# closely 390
# cloud 190
# code 2089
# coding 582
# collaborate 360
# communicate 338
# communication 510
# companies 228
# company 1264
# complete 222
# completion 197
# complex 523
# ...

# %%
list_count_job_desc= list(dist)
list_job_desc = list(job_descr)

# %%
#now create new data frame for this new count of words results to make its visualisation

# %%
data_frame_dsec= pd.DataFrame(list_count_job_desc)

# %%
data_frame_dsec['list_desc'] = pd.Series(list_job_desc, index=data_frame_dsec.index)

# %%
"""data_frame_dsec['count_list_desc'] = pd.Series(list_count_job_desc, index=data_frame_dsec.index)"""
# Out:
# "data_frame_dsec['count_list_desc'] = pd.Series(list_count_job_desc, index=data_frame_dsec.index)"

# %%
data_frame_dsec.head(10)
# Out:
#      0       list_desc
# 0  875         ability
# 1  359            able
# 2  496           about
# 3  217          access
# 4  358       according
# 5  344          across
# 6  553      activities
# 7  309  administration
# 8  271        advanced
# 9  271           agile

# %%
dist1 = np.sum(train_data_requ_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set

for tag, count in zip(job_requir, dist1):
    print tag,count
# Out:
# ability 2837
# able 644
# about 279
# across 113
# active 109
# administration 403
# adobe 126
# advanced 267
# advantage 156
# agile 495
# ajax 561
# all 349
# also 139
# an 1009
# analysis 493
# analytical 568
# and 20030
# android 765
# angular 148
# angularjs 219
# any 455
# apache 143
# api 281
# apis 449
# app 244
# application 933
# applications 1200
# apply 152
# approach 126
# apps 340
# arabic 189
# architecture 346
# architectures 147
# are 711
# as 1656
# asp 778
# asset 187
# at 999
# attention 256
# attitude 129
# automated 109
# awareness 112
# bachelor 1150
# back 128
# background 445
# based 432
# basic 482
# be 1389
# best 349
# big 167
# bootstrap 281
# both 428
# browser 151
# bs 325
# bsc 159
# build 145
# building 354
# business 884
# but 247
# by 154
# can 273
# candidate 203
# candidates 146
# ccna 119
# certification 183
# certified 175
# clean 133
# clear 120
# client 272
# clients 111
# cloud 179
# cms 157
# cocoa 104
# code 610
# codeigniter 121
# ...

# %%
list_count_job_req= list(dist1)
list_job_req = list(job_requir)
data_frame_req = pd.DataFrame(list_count_job_req)

# %%
"""data_frame_req['count_list_req'] = pd.Series(list_count_job_req, index=data_frame_req.index)"""
# Out:
# "data_frame_req['count_list_req'] = pd.Series(list_count_job_req, index=data_frame_req.index)"

# %%
data_frame_req['list_req'] = pd.Series(list_job_req, index=data_frame_req.index)

# %%
data_frame_req.head()
# Out:
#       0 list_req
# 0  2837  ability
# 1   644     able
# 2   279    about
# 3   113   across
# 4   109   active

# %%
# Sum up the counts of each vocabulary word
dist2 = np.sum(train_data_title_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(job_title, dist2):
    print count, tag
# Out:
# 2 000
# 2 13
# 13 15
# 4 2013
# 6 30
# 5 3d
# 3 500
# 2 6th
# 2 75
# 6 abap
# 16 account
# 6 accounting
# 25 adf
# 19 admin
# 4 administration
# 188 administrator
# 10 adminstrator
# 2 adsl
# 48 agent
# 3 agile
# 3 ai
# 2 alexanderia
# 158 alexandria
# 132 analyst
# 53 and
# 3 andriod
# 262 android
# 12 angular
# 17 angularjs
# 3 apex
# 18 app
# 149 application
# 48 applications
# 31 apps
# 2 arabia
# 54 architect
# 2 architecture
# 4 artificial
# 65 asp
# 13 assistant
# 13 associate
# 35 assurance
# 4 aswan
# 4 asyut
# 14 at
# 2 atg
# 2 atm
# 1 auditor
# 1 autocad
# 1 autodesk
# 10 automation
# 1 automotive
# 3 avaya
# 2 aws
# 29 ax
# 1 azure
# 2 b1
# 32 back
# 23 backend
# 5 background
# 7 banking
# 2 base
# 3 based
# 2 basis
# 14 bi
# 13 big
# 1 billing
# 1 biomedical
# 3 biztalk
# 1 bobj
# 1 boy
# 6 bpm
# 3 branches
# 1 bss
# 1 build
# 1 building
# 110 business
# 3 bw
# 5 by
# 4 cairo
# 1 cakephp
# 3 call
# 2 canada
# 2 capacity
# 1 care
# 1 case
# 1 cassandra
# 1 ccna
# 1 ce
# ...

# %%
list_count_job_title= list(dist2)
list_job_title= list(job_title)
data_frame_title = pd.DataFrame(list_count_job_title)

# %%
data_frame_title['list_title'] = pd.Series(list_job_title, index=data_frame_title.index)

# %%
data_frame_title.head(20)
# Out:
#       0      list_title
# 0     2             000
# 1     2              13
# 2    13              15
# 3     4            2013
# 4     6              30
# 5     5              3d
# 6     3             500
# 7     2             6th
# 8     2              75
# 9     6            abap
# 10   16         account
# 11    6      accounting
# 12   25             adf
# 13   19           admin
# 14    4  administration
# 15  188   administrator
# 16   10    adminstrator
# 17    2            adsl
# 18   48           agent
# 19    3           agile

# %%
data_frame_title.columns=['counts','list_title']

# %%
data_frame_title.head(10)
# Out:
#    counts list_title
# 0       2        000
# 1       2         13
# 2      13         15
# 3       4       2013
# 4       6         30
# 5       5         3d
# 6       3        500
# 7       2        6th
# 8       2         75
# 9       6       abap

# %%
data_frame_req.columns=['counts','list_req']

# %%
data_frame_req.head()
# Out:
#    counts list_req
# 0    2837  ability
# 1     644     able
# 2     279    about
# 3     113   across
# 4     109   active

# %%
data_frame_dsec.columns=['counts','list_desc']

# %%
data_frame_dsec.head()
# Out:
#    counts  list_desc
# 0     875    ability
# 1     359       able
# 2     496      about
# 3     217     access
# 4     358  according

# %%
"""
Lemmatisation (or lemmatization) in linguistics, is the process of grouping together
the different inflected forms of a word so they can be analysed as a single item.

"""
# Out:
# '\nLemmatisation (or lemmatization) in linguistics, is the process of grouping together\nthe different inflected forms of a word so they can be analysed as a single item.\n\n'

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
job_titel_lim=[lemmatizer.lemmatize(w) for w in data_frame_title['list_title']]

# %%
job_desc_lim=[lemmatizer.lemmatize(w) for w in data_frame_dsec['list_desc']]

# %%
job_req_lim=[lemmatizer.lemmatize(w) for w in data_frame_req['list_req']]

# %%
data_frame_dsec['new_list']=job_desc_lim

# %%
data_frame_dsec.drop(['list_desc'],axis=1,inplace=True)

# %%
data_frame_dsec.head()
# Out:
#    counts   new_list
# 0     875    ability
# 1     359       able
# 2     496      about
# 3     217     access
# 4     358  according

# %%
data_frame_title['new_list']=job_titel_lim

# %%
data_frame_title.drop(['list_title'],axis=1,inplace=True)

# %%
data_frame_title.head(20)
# Out:
#     counts        new_list
# 0        2             000
# 1        2              13
# 2       13              15
# 3        4            2013
# 4        6              30
# 5        5              3d
# 6        3             500
# 7        2             6th
# 8        2              75
# 9        6            abap
# 10      16         account
# 11       6      accounting
# 12      25             adf
# 13      19           admin
# 14       4  administration
# 15     188   administrator
# 16      10    adminstrator
# 17       2            adsl
# 18      48           agent
# 19       3           agile

# %%
data_frame_req['new_list']=job_req_lim

# %%
data_frame_req.drop(['list_req'],axis=1,inplace=True)

# %%
data_frame_req.head()
# Out:
#    counts new_list
# 0    2837  ability
# 1     644     able
# 2     279    about
# 3     113   across
# 4     109   active

# %%
#Drop duplicates 
data_frame_dsec.drop_duplicates(['new_list'],take_last=True)
# Out:
# C:\anaconda\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: the take_last=True keyword is deprecated, use keep='last' instead
#   from ipykernel import kernelapp as app
#      counts        new_list
# 0       875         ability
# 1       359            able
# 2       496           about
# 3       217          access
# 4       358       according
# 5       344          across
# 6       553        activity
# 7       309  administration
# 8       271        advanced
# 9       271           agile
# 10      226            ajax
# 11     1798             all
# 12      480            also
# 13     1596              an
# 14     1202        analysis
# 15      451         analyze
# 16      243       analyzing
# 17    39214             and
# 18      619         android
# 19      489             any
# 20      198            apis
# 21      233             app
# 23     3442     application
# 24      274           apply
# 25      395     appropriate
# 26      491            apps
# ...

# %%
data_frame_title.drop_duplicates(['new_list'],take_last=True)
# Out:
# C:\anaconda\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: the take_last=True keyword is deprecated, use keep='last' instead
#   if __name__ == '__main__':
#      counts        new_list
# 0         2             000
# 1         2              13
# 2        13              15
# 3         4            2013
# 4         6              30
# 5         5              3d
# 6         3             500
# 7         2             6th
# 8         2              75
# 9         6            abap
# 10       16         account
# 11        6      accounting
# 12       25             adf
# 13       19           admin
# 14        4  administration
# 15      188   administrator
# 16       10    adminstrator
# 17        2            adsl
# 18       48           agent
# 19        3           agile
# 20        3              ai
# 21        2     alexanderia
# 22      158      alexandria
# 23      132         analyst
# 24       53             and
# 25        3         andriod
# ...

# %%
data_frame_req.drop_duplicates(['new_list'],take_last=True)
# Out:
# C:\anaconda\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: the take_last=True keyword is deprecated, use keep='last' instead
#   if __name__ == '__main__':
#      counts        new_list
# 0      2837         ability
# 1       644            able
# 2       279           about
# 3       113          across
# 4       109          active
# 5       403  administration
# 6       126           adobe
# 7       267        advanced
# 8       156       advantage
# 9       495           agile
# 10      561            ajax
# 11      349             all
# 12      139            also
# 13     1009              an
# 14      493        analysis
# 15      568      analytical
# 16    20030             and
# 17      765         android
# 18      148         angular
# 19      219       angularjs
# 20      455             any
# 21      143          apache
# 22      281             api
# 23      449            apis
# 24      244             app
# 26     1200     application
# ...

# %%
#now export this dataframe to tableau for visualisation it

# %%
data_frame_dsec.to_csv('E:/ffinaal/job_desc.csv', sep='\t',encoding='utf8')
data_frame_req.to_csv('E:/ffinaal/job_req.csv', sep='\t',encoding='utf8')
data_frame_title.to_csv('E:/ffinaal/job_title.csv', sep='\t',encoding='utf8')
